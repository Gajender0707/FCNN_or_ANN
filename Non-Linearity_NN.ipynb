# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#     f1   f2   Target
# 0  1.0  5.1  15.1728
# 1  2.0  5.4  17.3722
# 2  3.0  5.7  19.5716
# 3  4.0  6.0  21.7710
# 4  5.0  6.3  23.9704

# %%
y=data.Target

# %%
x=data.drop("Target",axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
x_train.shape
# Out:
# (33, 2)

# %%
x_test.shape
# Out:
# (17, 2)

# %%
y_train.shape
# Out:
# (33,)

# %%
y_test.shape
# Out:
# (17,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adagrad
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Sigmoid

# %%
def baseline_model():
    model=Sequential()
    model.add(Dense(30,input_dim=2,activation="sigmoid"))
    model.add(Dense(20,activation="sigmoid"))
    model.add(Dense(10,activation="sigmoid"))
    model.add(Dense(1))
    opt=Adam(learning_rate=0.01)
    model.compile(loss="mean_squared_error",optimizer=opt)
    return model

# %%
model=baseline_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 30)                90
#
#  dense_1 (Dense)             (None, 20)                620
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# ...
# Total params: 931
# Trainable params: 931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,verbose=1,batch_size=20,epochs=100,validation_data=(x_test,y_test)) #validation_data is the test data
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 260ms/step - loss: 757.9653 - val_loss: 785.9471
# Epoch 2/100
# 2/2 [==============================] - 0s 42ms/step - loss: 729.9514 - val_loss: 759.9755
# Epoch 3/100
# 2/2 [==============================] - 0s 42ms/step - loss: 703.8103 - val_loss: 736.8891
# Epoch 4/100
# 2/2 [==============================] - 0s 45ms/step - loss: 681.2585 - val_loss: 716.9656
# Epoch 5/100
# 2/2 [==============================] - 0s 41ms/step - loss: 661.8825 - val_loss: 700.2192
# Epoch 6/100
# 2/2 [==============================] - 0s 43ms/step - loss: 645.2029 - val_loss: 686.3638
# Epoch 7/100
# 2/2 [==============================] - 0s 40ms/step - loss: 631.7823 - val_loss: 674.8262
# Epoch 8/100
# 2/2 [==============================] - 0s 41ms/step - loss: 620.3373 - val_loss: 665.0215
# Epoch 9/100
# 2/2 [==============================] - 0s 43ms/step - loss: 610.8198 - val_loss: 656.3739
# Epoch 10/100
# ...

# %%
yp=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# -1.3360688897110888

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# 16.55632759457745

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
r2_score(y_test,y_pred)
# Out:
# 16.55632759457745
# -1.3360688897110888

# %% [markdown]
# # tanh

# %%
def baseline_model():
    model=Sequential()
    model.add(Dense(30,input_dim=2,activation="tanh"))
    model.add(Dense(20,activation="tanh"))
    model.add(Dense(10,activation="tanh"))
    model.add(Dense(1))
    opt=Adam(learning_rate=0.01)
    model.compile(loss="mean_squared_error",optimizer=opt)
    return model

# %%
model=baseline_model()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 30)                90
#
#  dense_5 (Dense)             (None, 20)                620
#
#  dense_6 (Dense)             (None, 10)                210
#
#  dense_7 (Dense)             (None, 1)                 11
#
# ...
# Total params: 931
# Trainable params: 931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,verbose=1,batch_size=20,epochs=100,validation_data=(x_test,y_test)) #validation_data is the test data
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 212ms/step - loss: 763.8062 - val_loss: 699.3400
# Epoch 2/100
# 2/2 [==============================] - 0s 38ms/step - loss: 623.9824 - val_loss: 636.7312
# Epoch 3/100
# 2/2 [==============================] - 0s 43ms/step - loss: 573.2900 - val_loss: 606.1639
# Epoch 4/100
# 2/2 [==============================] - 0s 40ms/step - loss: 545.1740 - val_loss: 577.1706
# Epoch 5/100
# 2/2 [==============================] - 0s 36ms/step - loss: 517.9877 - val_loss: 557.0622
# Epoch 6/100
# 2/2 [==============================] - 0s 43ms/step - loss: 499.7477 - val_loss: 543.9135
# Epoch 7/100
# 2/2 [==============================] - 0s 41ms/step - loss: 487.2166 - val_loss: 533.5283
# Epoch 8/100
# 2/2 [==============================] - 0s 41ms/step - loss: 477.0866 - val_loss: 524.1477
# Epoch 9/100
# 2/2 [==============================] - 0s 45ms/step - loss: 467.7845 - val_loss: 515.0461
# Epoch 10/100
# ...

# %%
y_pred=model.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
r2_score(y_test,y_pred)
# Out:
# 11.840844174161631
# -0.19487632260811827

# %% [markdown]
# # relu

# %%
def baseline_model():
    model=Sequential()
    model.add(Dense(30,input_dim=2,activation="relu"))
    model.add(Dense(20,activation="relu"))
    model.add(Dense(10,activation="relu"))
    model.add(Dense(1))
    opt=Adam(learning_rate=0.01)
    model.compile(loss="mean_squared_error",optimizer=opt)
    return model

# %%
model=baseline_model()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 30)                90
#
#  dense_9 (Dense)             (None, 20)                620
#
#  dense_10 (Dense)            (None, 10)                210
#
#  dense_11 (Dense)            (None, 1)                 11
#
# ...
# Total params: 931
# Trainable params: 931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,verbose=1,batch_size=20,epochs=100,validation_data=(x_test,y_test)) #validation_data is the test data
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 240ms/step - loss: 814.5671 - val_loss: 749.5353
# Epoch 2/100
# 2/2 [==============================] - 0s 49ms/step - loss: 690.5945 - val_loss: 701.4291
# Epoch 3/100
# 2/2 [==============================] - 0s 47ms/step - loss: 641.8581 - val_loss: 639.3866
# Epoch 4/100
# 2/2 [==============================] - 0s 55ms/step - loss: 582.8751 - val_loss: 573.0375
# Epoch 5/100
# 2/2 [==============================] - 0s 52ms/step - loss: 522.7656 - val_loss: 498.5665
# Epoch 6/100
# 2/2 [==============================] - 0s 55ms/step - loss: 447.8510 - val_loss: 413.1756
# Epoch 7/100
# 2/2 [==============================] - 0s 55ms/step - loss: 369.3819 - val_loss: 317.1332
# Epoch 8/100
# 2/2 [==============================] - 0s 53ms/step - loss: 280.6857 - val_loss: 215.8261
# Epoch 9/100
# 2/2 [==============================] - 0s 70ms/step - loss: 184.7371 - val_loss: 118.6747
# Epoch 10/100
# ...

# %%
y_pred=model.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
r2_score(y_test,y_pred)
# Out:
# 0.18918207768284187
# 0.999694987522966

# %%
from tensorflow.keras.layers import LeakyReLU

# %% [markdown]
# # LeakyReLU

# %%
def baseline_model():
    model=Sequential()
    model.add(Dense(30,input_dim=2,activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(20,activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(10,activation=LeakyReLU(alpha=0.1)))
    model.add(Dense(1))
    opt=Adam(learning_rate=0.01)
    model.compile(loss="mean_squared_error",optimizer=opt)
    return model

# %%
model=baseline_model()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 30)                90
#
#  dense_13 (Dense)            (None, 20)                620
#
#  dense_14 (Dense)            (None, 10)                210
#
#  dense_15 (Dense)            (None, 1)                 11
#
# ...
# Total params: 931
# Trainable params: 931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,verbose=1,batch_size=20,epochs=100,validation_data=(x_test,y_test)) #validation_data is the test data
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 210ms/step - loss: 692.0122 - val_loss: 685.6888
# Epoch 2/100
# 2/2 [==============================] - 0s 49ms/step - loss: 622.3012 - val_loss: 581.6965
# Epoch 3/100
# 2/2 [==============================] - 0s 46ms/step - loss: 520.9423 - val_loss: 442.8579
# Epoch 4/100
# 2/2 [==============================] - 0s 59ms/step - loss: 385.1233 - val_loss: 273.5575
# Epoch 5/100
# 2/2 [==============================] - 0s 43ms/step - loss: 222.5287 - val_loss: 95.4910
# Epoch 6/100
# 2/2 [==============================] - 0s 43ms/step - loss: 64.4123 - val_loss: 0.6999
# Epoch 7/100
# 2/2 [==============================] - 0s 42ms/step - loss: 7.9210 - val_loss: 90.6172
# Epoch 8/100
# 2/2 [==============================] - 0s 49ms/step - loss: 93.9829 - val_loss: 123.0112
# Epoch 9/100
# 2/2 [==============================] - 0s 45ms/step - loss: 95.2606 - val_loss: 48.8453
# Epoch 10/100
# ...

# %%
y_pred=model.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
r2_score(y_test,y_pred)
# Out:
# 0.039279155062773324
# 0.9999868513278183
